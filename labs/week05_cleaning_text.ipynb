# %% [markdown]
# In this activity, you will write question answer program and integrate it with chatbot.

# %% [markdown]
# ## Part 1. Question and answer

# %% [markdown]
# First, you will install ntlk corpuses.
#
# Run the following cell.

# %%
import nltk

# %%
nltk.download("stopwords")
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/prashanththattai/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/prashanththattai/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### 1. Compare dictionary to find answer

# %% [markdown]
# In this task, you will extend your chatbot to answer questions from data.
#
# This involves three parts:
# - Writing a procedure to compare two dictionaries
# - Preprocess sentnences and make them into dictionaries

# %% [raw]
# Here are two sample dictionaries.
#
# ques = {"subject": "who", "verb": "chased", "object": ball }
# data = {"subject": "the dog", "verb": "chased", "object": "the ball" }
#
# Follow the lecture code and write the procedure to compare and find an answer from these two dictionaries.

# %%
def compare_dict( ____ ):

    # Fill in this code from lecture

# %% [markdown]
# Expected output:
# The dog

# %% [markdown]
# ### 2. Preprocess sentences

# %% [markdown]
# Follow the lecture code and write the procedure to preprocess and make sentences to dictionaries.
#
# First import stopwords, word_tokenize and lemmatizer from nltk.

# %%
def pre_process( ____ ):

    # Fill in this code from lecture

# %%
Try this on a few sentences. 

- The fat cat sat on the mat
- The boy ran from the crocodile

See how preprocessing gets only essential parts of sentence.

# %% [markdown]
# ### 3. Use preprocessed sentence to find answer
#
# First, use the regex pattern from lecture that can capture subject-verb-object.

# %%
## Fill in this from lecture

# %% [markdown]
# We will write a procedure to find answer that uses previous functions.
#
# In the find_answer functon,
#
# - preprocess the question, and the sentence
# - create dictionaries using re.search
# - compare dictionaries to find answer

# %%
def find_answer( question):

    sentence = "the dog chased the ball"
    pat = "_______" #fill this from lecture
    
    # Preprocess
    # Create dictionaries 
    # Compare and find answer

# %% [markdown]
# #### At this point, contact your tutors and show the outputs

# %% [markdown]
# ## Part 2. Integrating with chatbot
#
# There are many ways to integrate this into chatbot. Here's a simple way that does not interfere with rest of the code.

# %%
def chatbot_main():

    userinput = input("Type")

    while True:
        if userinput == "quit":
            break
    
        elif userinput[len(userinput)-1] == "?": # if the sentence ends with a question mark
            print(find_answer(userinput))
    
        else:
            print(pattern_matching(userinput)) # This is old code from last weeks

# %% [markdown]
# If you can think of a more elegant way to do it, discuss it with tutors.
