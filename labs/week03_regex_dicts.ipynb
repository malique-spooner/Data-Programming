# %% [markdown]
# #### Eliza chatbot
#
# This example demonstrates how to build an ELIZA using single and two variable patterns.

# %%
import re

# %% [markdown]
# ### 2.1 Create dictionary of patterns and responses
#
# ```python
#
# Look at the following conversation snippet to create a dictionary of patterns for Eliza chatbot.
#
# The keys of dictionary are regular expression. Values are associated template responses.
#
# E.g.,
#
# dict1 = {
#              r"I need a (?P<y>\w+)": "What does it mean for you to get a {y}"
#              ..
#              .. and more patterns like this
# }
#
# Start by creating 2-3 patterns at a time by looking at first three user and Eliza's sentences of the conversation.
#
# Once you feel confident about 3 you have written, move on to 2.2 and finish the rest of the code.

# %% [markdown]
# ---
#
# **User:** **Hello** there.
# **ELIZA:** Hello. How can I help you today?
#
# **User:** **I want to feel** less anxious.
# **ELIZA:** Why do you want to feel less anxious?
#
# **User:** **Because** I don’t sleep enough.
# **ELIZA:** Is that the real reason?
#
# **User:** **I feel** tired all the time.
# **ELIZA:** Do you often feel tired all the time?
#
# **User:** **Yes**, that’s exactly it.
# **ELIZA:** You seem quite positive.
#
# **User:** **No**, I don’t think so.
# **ELIZA:** Why not?
#
# **User:** Well, **maybe** it’s just stress.
# **ELIZA:** You don’t sound completely certain.
#
# **User:** **I remember** feeling like this before exams.
# **ELIZA:** Does feeling like this before exams remind you of something?
#
# **User:** It feels **like** everything is heavy lately.
# **ELIZA:** In what way is it that it feels like everything is heavy lately?
#
# (This occurs when no specific pattern matches the user’s input.)\
# **User:** I keep trying to change, but nothing works.
# **ELIZA:** *That’s very interesting.*
#
# **User:** **Maybe** that’s enough for today.
# **ELIZA:** You don’t sound completely certain.
#
# ---

# %% [markdown]
# ## 2.2 Pattern substitution
#
# Adapt the pattern matching and substitution code from the VLE short video.
# - Pattern matching and substitution: [https://learn.gold.ac.uk/mod/lti/view.php?id=1750343)]
# - Multiple groups and Dot operator: [https://learn.gold.ac.uk/mod/lti/view.php?id=1750344]

# %% [markdown]
# #### To complete
#
# - Define a function named use_eliza_rules that takes one argument, sentence, which is the user’s input (a string).
#
# - Write a for loop to Loop through every key (k) in the dictionary eliza_rules.
#
# - Adapt pattern matching video code
#
#     - **Example**: if the regex was r"my name is (?P<name>\w+)" and input was "my name is John", then dictmatch = {"name": "John"}.
#
#
# - Return the completed response (e.g., "Hello John, how are you today?").

# %% [markdown]
# ## 2.3 Chatbot rules
#
# Chatbot is a continuous:
# - Get user input
# - Checks if user wants to quit and terminates
# - Or, else pass the user input to Eliza and print response.

# %% [markdown]
# ### <span style="color:red;"> Discuss with your tutor:
#
# 1. Increase the responses available for each pattern.
#
#     - LLM Generator prompt:
#       *I am developing an Eliza chatbot in Python using regular expressions for pattern matching. Give me more responses
#       for the pattern*
#          *Pattern: r'I want to feel (?P<y>.*)'*
#          *Response: "Why do you want to feel {y}"*
#
#       Copy 3-4 from the response that makes sense and add it to the response.
#     - **Note that as you make more responses , you have use to put them in a list.**
#
# 2. Increase the patterns you use in the chatbot.
#     - If you feel confident, start creating more patterns.
#     - See if you can write patterns that capture date and time.
#
#
# 3. Use memory when there is no match.
#     - Create a global variable called "memory" and make it an empty list.
#     - Append each matched variable to the memory.
#     - Pick a random variable from memory, and add it to the template:
#       - "Earlier you mentioned about {X}, can you tell me more?"
#
# 4. Can you use Eliza to add a new rule?
#     - This is a fascinating topic and is a turn towards system that learn.
#
# Other enhancements that you can think of for the chatbot.
